# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Zomato.csv")

# %%
df.shape
# Out:
# (148, 7)

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
def handlwRate(value):

    value= str(value).split("/")
    value =value[0]
    return value

# %%
df['rate']=df['rate'].apply(handlwRate)

# %%
df
# Out:
#                       name online_order book_table rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1    775
# 1           Spice Elephant          Yes         No  4.1    787
# 2          San Churro Cafe          Yes         No  3.8    918
# 3    Addhuri Udupi Bhojana           No         No  3.7     88
# 4            Grand Village           No         No  3.8    166
# ..                     ...          ...        ...  ...    ...
# 143       Melting Melodies           No         No  3.3      0
# 144        New Indraprasta           No         No  3.3      0
# 145           Anna Kuteera          Yes         No  4.0    771
# 146                 Darbar           No         No  3.0     98
# 147          Vijayalakshmi          Yes         No  3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# 2                            800          Buffet
# ...

# %%
df['listed_in(type)'].value_counts()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
sns.countplot(x=df['listed_in(type)'])
plt.xlabel('type of resturant')
# Out:
# Text(0.5, 0, 'type of resturant')

# %%
df.groupby("listed_in(type)")['votes'].sum(
    
)
# Out:
# listed_in(type)
# Buffet     3028
# Cafes      6434
# Dining    20363
# other      9367
# Name: votes, dtype: int64

# %%
df.head()
# Out:
#                     name online_order book_table rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1    775
# 1         Spice Elephant          Yes         No  4.1    787
# 2        San Churro Cafe          Yes         No  3.8    918
# 3  Addhuri Udupi Bhojana           No         No  3.7     88
# 4          Grand Village           No         No  3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df['rate'].value_counts()
# Out:
# rate
# 3.8     19
# 3.7     15
# 3.3     14
# 3.4     12
# 3.6     11
# 4.1     11
# 3.9     10
# 4.0     10
# 4.2      8
# 3.2      7
# 2.9      7
# 3.1      7
# 3.5      6
# 4.6      2
# 3.0      2
# 2.8      2
# 4.4      2
# 4.3      1
# 2.6      1
# 3.8      1
# Name: count, dtype: int64

# %%
plt.hist(df['rate'],bins=20)
plt.title("ratings distribution")
# Out:
# Text(0.5, 1.0, 'ratings distribution')

# %%
df['rate'].value_counts().sort_index().plot(kind='bar')
plt.title("Exact Ratings Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df.head()
# Out:
#                     name online_order book_table rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1    775
# 1         Spice Elephant          Yes         No  4.1    787
# 2        San Churro Cafe          Yes         No  3.8    918
# 3  Addhuri Udupi Bhojana           No         No  3.7     88
# 4          Grand Village           No         No  3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df['online_order'].value_counts()
# Out:
# online_order
# No     90
# Yes    58
# Name: count, dtype: int64

# %%
df.groupby('online_order')['approx_cost(for two people)'].sum()
# Out:
# online_order
# No     32300
# Yes    29600
# Name: approx_cost(for two people), dtype: int64

# %%
29600/58
# Out:
# 510.3448275862069

# %%
df.groupby('online_order')['rate'].max()
# Out:
# online_order
# No     4.3
# Yes    4.6
# Name: rate, dtype: object

# %%
df[df['online_order'] =='No']['listed_in(type)'].value_counts()
# Out:
# listed_in(type)
# Dining    77
# Cafes      8
# Buffet     3
# other      2
# Name: count, dtype: int64
